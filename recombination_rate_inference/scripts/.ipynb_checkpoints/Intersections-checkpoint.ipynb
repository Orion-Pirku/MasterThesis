# %%
import pybedtools
import pandas as pd
import numpy as np
import plotly.express as px
import glob
from multiprocessing import Pool, cpu_count
from pathlib import Path
from typing import List, Optional

# %%
def process_file(file: str) -> pybedtools.BedTool:
    try:
        return pybedtools.BedTool(Path(file))
    except Exception as e:
        print(f"Failed to process {file}: {e}")
        return None

def parse_bed_files(file_pattern: str) -> List[pybedtools.BedTool]:
    file_names = glob.glob(file_pattern, recursive=True)
    if not file_names:
        raise FileNotFoundError(f"No files matched pattern: {file_pattern}")
    
    with Pool(processes=max(cpu_count() // 2, 1)) as pool:
        bedtools_list = pool.map(process_file, file_names)

    # Filter out failed results (None)
    return [bt for bt in bedtools_list if bt is not None]

bedfiles = parse_bed_files("../output/transformed_*_w10000.tsv")

# %%
bed = bedfiles[0].to_dataframe()
print(bed.head(10))
# Out:
#    chrom  start     end       name  score
# 0  chr15      0   10000   0.908066   5000
# 1  chr15  10000   20000   0.034987  15000
# 2  chr15  20000   30000   0.046084  25000
# 3  chr15  30000   40000   1.101715  35000
# 4  chr15  40000   50000   0.457738  45000
# 5  chr15  50000   60000   1.292832  55000
# 6  chr15  60000   70000   0.464157  65000
# 7  chr15  70000   80000   0.166398  75000
# 8  chr15  80000   90000   0.641467  85000
# 9  chr15  90000  100000  11.559163  95000

# %%
bedfiles[0][1]
# Out:
# Interval(chr15:10000-20000)
