# %%
import pandas as pd
import numpy as np
import scipy as sp
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from pybedtools import BedTool
from glob import glob
from multiprocessing import Pool, cpu_count
from typing import List, Tuple, Dict, Mapping, Union, Literal
import pyranges as pr
import numpy.typing as npt
from functools import partial

# %%
def read_bed_file(file: str) -> pd.DataFrame:
    return pd.read_csv(file, sep = '\t', 
                       header = None, 
                       names=['Chromosome', 'Start', 'End', 'Score', 'Mindpoint'], 
                       skiprows = 1)

def parse_and_merge_bed(input_files: str, 
                        return_type: Literal["bed", "pyranges", "dataframe"] = "dataframe" 
                       ) -> Union[BedTool, pd.DataFrame, pr.PyRanges]:
    file_paths = glob(input_files, recursive=True)
    with Pool(processes=cpu_count() // 2) as pool:
        dfs = pool.map(read_bed_file, file_paths)
    merged_df = pd.concat(dfs, ignore_index=True).sort_values(by=["Chromosome", "Start"]).reset_index().iloc[:, 1:]
    match return_type:
        case "bed":
            return BedTool.from_dataframe(merged_df)
        case "dataframe":
            return merged_df
        case "pyranges":
            return pr.PyRanges(merged_df)
        case _:
            raise ValueError(f"Unknown return_type: {return_type}")

rec_rate_10kb = parse_and_merge_bed("../output/transformed_*_w10000.tsv", return_type="bed")

# %%
def transform_feature_table(
    gff_object: Union[pd.DataFrame, BedTool],
    chr_pattern: str = r"chr([1-9]|[12][0-9]|3[0-3])$",
    return_type: Literal["bed", "dataframe", "pyranges"] = "dataframe"
) -> BedTool:
    if isinstance(gff_object, BedTool):
        gff = gff_object.to_dataframe()
    elif isinstance(gff_object, pd.DataFrame):
        gff = gff_object.copy()
    else:
        raise TypeError("Input must be a pandas DataFrame or a BedTool object")

    required_columns: List[str] = ["chromosome", "start", "end", "# feature", "name", "symbol"]
    missing = set(required_columns) - set(gff.columns)
    if missing:
        raise ValueError(f"Missing columns: {missing}")

    df_transformed = (
        gff
        .filter(items=required_columns)
        .assign(
            start=lambda df: df["start"].astype("int64"),
            end=lambda df: df["end"].astype("int64"),
            chromosome=lambda df: "chr" + df["chromosome"].astype(str)
        )
        .loc[lambda df: df["chromosome"].str.match(chr_pattern)]
    )

    # Rename 'chromosome' to 'chrom' because BedTool expects 'chrom' as the first column
    df_transformed = df_transformed.rename(
        columns={"chromosome": "Chromosome",
                 "start": "Start",
                 "end": "End",
                 "# feature": "Feature",
                 "symbol": "Symbol",
                 "name": "Name"})

    # Reorder columns so that chrom, start, end are first 3 columns (required for BedTool)
    bedtool_columns = ["Chromosome", "Start", "End", "Feature", "Symbol"]
    df_transformed = df_transformed[bedtool_columns]
    df_sorted = df_transformed.sort_values(by=["Chromosome", "Start"]).reset_index(drop=True)

    match return_type:
        case "bed":
            return BedTool.from_dataframe(df_sorted)
        case "dataframe":
            return df_sorted
        case "pyranges":
            return pr.PyRanges(df_sorted)
        case _:
            raise ValueError(f"Unknown return_type: {return_type}")


blackcap_feature_table = pd.read_csv("../input/GCF_009819655.1_bSylAtr1.pri_feature_table.txt", sep = '\t', header = 0, dtype=str)

blackcap_gff = transform_feature_table(blackcap_feature_table, return_type="bed")
blackcap_gff.head()
# Out:
# chr1	12841	20557	gene	LOC136375641
#  chr1	12841	20557	ncRNA	LOC136375641
#  chr1	14799	20557	ncRNA	LOC136375641
#  chr1	25612	99186	gene	SMARCD3
#  chr1	25612	99186	mRNA	SMARCD3
#  chr1	25612	77302	mRNA	SMARCD3
#  chr1	25612	75246	mRNA	SMARCD3
#  chr1	27102	77287	CDS	SMARCD3
#  chr1	27102	75003	CDS	SMARCD3
#  chr1	27102	64579	CDS	SMARCD3

# %%
def split_bedtool_by_feature(input_bed: pr.PyRanges | pd.DataFrame | BedTool) -> dict[str, Union[pr.PyRanges, BedTool, pd.DataFrame]]:
    if isinstance(input_bed, pr.PyRanges):
        df = input_bed.df
    elif isinstance(input_bed, pd.DataFrame):
        df = input_bed.copy()
    else:
        raise TypeError("Input must be a pandas DataFrame or a BedTool object")
    
    if df.shape[1] < 4:
        raise ValueError("Expected at least 4 columns in the BedTool Data Format (chrom, start, end, features)")

    feature_dict: Dict[str, BedTool] = {}

    unique_features = df.iloc[:, 3].unique()
    
    for feature in unique_features:
        df_feature = df[df.iloc[:, 3]== feature]
        feature_dict[feature] = pr.PyRanges(df_feature)
    return feature_dict
    
features = split_bedtool_by_feature(blackcap_gff)
features
# Out:
# {'gene': +--------------+-----------+-----------+------------+--------------+
#  | Chromosome   | Start     | End       | Feature    | Symbol       |
#  | (category)   | (int64)   | (int64)   | (object)   | (object)     |
#  |--------------+-----------+-----------+------------+--------------|
#  | chr1         | 12841     | 20557     | gene       | LOC136375641 |
#  | chr1         | 25612     | 99186     | gene       | SMARCD3      |
#  | chr1         | 101144    | 103863    | gene       | LOC136375677 |
#  | chr1         | 106819    | 112088    | gene       | CHPF2        |
#  | ...          | ...       | ...       | ...        | ...          |
#  | chr33        | 237393    | 239411    | gene       | LOC136373190 |
#  | chr33        | 251902    | 255491    | gene       | LOC136373191 |
#  | chr33        | 259609    | 260145    | gene       | LOC136373228 |
#  | chr33        | 286378    | 292821    | gene       | TCHH         |
#  +--------------+-----------+-----------+------------+--------------+
#  Unstranded PyRanges object has 16,457 rows and 5 columns from 33 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'ncRNA': +--------------+-----------+-----------+------------+--------------+
#  | Chromosome   | Start     | End       | Feature    | Symbol       |
#  | (category)   | (int64)   | (int64)   | (object)   | (object)     |
#  |--------------+-----------+-----------+------------+--------------|
#  | chr1         | 12841     | 20557     | ncRNA      | LOC136375641 |
#  | chr1         | 14799     | 20557     | ncRNA      | LOC136375641 |
#  | chr1         | 101144    | 103863    | ncRNA      | LOC136375677 |
#  | chr1         | 403376    | 403505    | ncRNA      | LOC136372976 |
#  | ...          | ...       | ...       | ...        | ...          |
#  | chr32        | 231871    | 231954    | ncRNA      | LOC136373148 |
#  | chr32        | 248771    | 249630    | ncRNA      | LOC136373134 |
#  | chr32        | 263416    | 263499    | ncRNA      | LOC136373149 |
#  | chr32        | 280167    | 281131    | ncRNA      | LOC136373137 |
#  +--------------+-----------+-----------+------------+--------------+
#  Unstranded PyRanges object has 2,172 rows and 5 columns from 32 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'mRNA': +--------------+-----------+-----------+------------+--------------+
#  | Chromosome   | Start     | End       | Feature    | Symbol       |
#  | (category)   | (int64)   | (int64)   | (object)   | (object)     |
#  |--------------+-----------+-----------+------------+--------------|
#  | chr1         | 25612     | 99186     | mRNA       | SMARCD3      |
#  | chr1         | 25612     | 77302     | mRNA       | SMARCD3      |
#  | chr1         | 25612     | 75246     | mRNA       | SMARCD3      |
#  | chr1         | 106819    | 112088    | mRNA       | CHPF2        |
#  | ...          | ...       | ...       | ...        | ...          |
#  | chr33        | 237393    | 239411    | mRNA       | LOC136373190 |
#  | chr33        | 251902    | 255491    | mRNA       | LOC136373191 |
#  | chr33        | 259609    | 260145    | mRNA       | LOC136373228 |
#  | chr33        | 286378    | 292821    | mRNA       | TCHH         |
#  +--------------+-----------+-----------+------------+--------------+
#  Unstranded PyRanges object has 26,215 rows and 5 columns from 33 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'CDS': +--------------+-----------+-----------+------------+--------------+
#  | Chromosome   | Start     | End       | Feature    | Symbol       |
#  | (category)   | (int64)   | (int64)   | (object)   | (object)     |
#  |--------------+-----------+-----------+------------+--------------|
#  | chr1         | 27102     | 77287     | CDS        | SMARCD3      |
#  | chr1         | 27102     | 75003     | CDS        | SMARCD3      |
#  | chr1         | 27102     | 64579     | CDS        | SMARCD3      |
#  | chr1         | 107037    | 111835    | CDS        | CHPF2        |
#  | ...          | ...       | ...       | ...        | ...          |
#  | chr33        | 237393    | 239411    | CDS        | LOC136373190 |
#  | chr33        | 251913    | 255491    | CDS        | LOC136373191 |
#  | chr33        | 259609    | 260145    | CDS        | LOC136373228 |
#  | chr33        | 286378    | 292820    | CDS        | TCHH         |
#  +--------------+-----------+-----------+------------+--------------+
#  Unstranded PyRanges object has 26,222 rows and 5 columns from 33 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'misc_RNA': +--------------+-----------+-----------+------------+--------------+
#  | Chromosome   | Start     | End       | Feature    | Symbol       |
#  | (category)   | (int64)   | (int64)   | (object)   | (object)     |
#  |--------------+-----------+-----------+------------+--------------|
#  | chr1         | 974447    | 1012239   | misc_RNA   | SETD2        |
#  | chr1         | 2270206   | 2276016   | misc_RNA   | GJC2         |
#  | chr1         | 4434078   | 4455804   | misc_RNA   | ACAA1        |
#  | chr1         | 13194129  | 13239954  | misc_RNA   | CREM         |
#  | ...          | ...       | ...       | ...        | ...          |
#  | chr30        | 1288433   | 1306264   | misc_RNA   | LOC136372994 |
#  | chr30        | 1288433   | 1306264   | misc_RNA   | LOC136372994 |
#  | chr30        | 1466138   | 1471956   | misc_RNA   | RNF115       |
#  | chr30        | 1466138   | 1471956   | misc_RNA   | RNF115       |
#  +--------------+-----------+-----------+------------+--------------+
#  Unstranded PyRanges object has 643 rows and 5 columns from 30 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'tRNA': +--------------+-----------+-----------+------------+------------+
#  | Chromosome   | Start     | End       | Feature    | Symbol     |
#  | (category)   | (int64)   | (int64)   | (object)   | (object)   |
#  |--------------+-----------+-----------+------------+------------|
#  | chr1         | 12558247  | 12558318  | tRNA       | TRNAG-UCC  |
#  | chr1         | 16202370  | 16202443  | tRNA       | TRNAN-GUU  |
#  | chr1         | 18304203  | 18304276  | tRNA       | TRNAN-GUU  |
#  | chr1         | 24433598  | 24433671  | tRNA       | TRNAN-GUU  |
#  | ...          | ...       | ...       | ...        | ...        |
#  | chr27        | 859513    | 859602    | tRNA       | TRNAI-UAU  |
#  | chr27        | 854321    | 854392    | tRNA       | TRNAC-GCA  |
#  | chr27        | 756412    | 756483    | tRNA       | TRNAC-GCA  |
#  | chr27        | 756143    | 756214    | tRNA       | TRNAC-GCA  |
#  | chr28        | 1212317   | 1212387   | tRNA       | TRNAG-CCC  |
#  | chr30        | 1926962   | 1927033   | tRNA       | TRNAM-CAU  |
#  | chr30        | 1317351   | 1317424   | tRNA       | TRNAR-UCU  |
#  +--------------+-----------+-----------+------------+------------+
#  Unstranded PyRanges object has 217 rows and 5 columns from 25 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'C_region': +--------------+-----------+-----------+------------+--------------+
#  | Chromosome   |     Start |       End | Feature    | Symbol       |
#  | (category)   |   (int64) |   (int64) | (object)   | (object)     |
#  |--------------+-----------+-----------+------------+--------------|
#  | chr2         |  25801973 |  25831429 | C_region   | LOC136375516 |
#  | chr2         |  25848445 |  25856180 | C_region   | LOC136375517 |
#  | chr27        |   2562171 |   2607886 | C_region   | LOC136372331 |
#  | chr27        |   2687278 |   2692035 | C_region   | LOC136372332 |
#  +--------------+-----------+-----------+------------+--------------+
#  Unstranded PyRanges object has 4 rows and 5 columns from 2 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'V_segment': +--------------+-----------+-----------+------------+--------------+
#  | Chromosome   |     Start |       End | Feature    | Symbol       |
#  | (category)   |   (int64) |   (int64) | (object)   | (object)     |
#  |--------------+-----------+-----------+------------+--------------|
#  | chr27        |   2748357 |   2749459 | V_segment  | LOC136372333 |
#  | chr27        |   2762137 |   2763262 | V_segment  | LOC136372095 |
#  | chr27        |   2782723 |   2784148 | V_segment  | LOC136372117 |
#  +--------------+-----------+-----------+------------+--------------+
#  Unstranded PyRanges object has 3 rows and 5 columns from 1 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.}

# %%
rho_gff_intersections = (
    rec_rate_10kb.intersect(blackcap_gff, wb=True)
    .sort()
    .to_dataframe()
    .rename(columns={"name": "cM_Mb",
                     "itemRgb": "feature",
                     "blockCount": "symbol",
                     "blockSizes": "description"
                    })
        )

rho_gff_intersections.head()
rho_gff_intersections['rho_strength'] = pd.qcut(rho_gff_intersections["cM_Mb"], q=3, labels=['low','medium','high']).astype("category")
rho_gff_intersections.head()
# Out:
#   chrom  start    end     cM_Mb  score strand  thickStart  thickEnd feature  \
# 0  chr1  12841  20000  7.233462  15000   chr1       12841     20557    gene
# 1  chr1  12841  20000  7.233462  15000   chr1       12841     20557   ncRNA
# 2  chr1  14799  20000  7.233462  15000   chr1       14799     20557   ncRNA
# 3  chr1  20000  20557  2.388083  25000   chr1       12841     20557   ncRNA
# 4  chr1  20000  20557  2.388083  25000   chr1       14799     20557   ncRNA
#
#          symbol                                    description rho_strength
# 0  LOC136375641                   uncharacterized LOC136375641       medium
# 1  LOC136375641  uncharacterized lncRNA, transcript variant X2       medium
# 2  LOC136375641  uncharacterized lncRNA, transcript variant X1       medium
# 3  LOC136375641  uncharacterized lncRNA, transcript variant X2          low
# 4  LOC136375641  uncharacterized lncRNA, transcript variant X1          low

# %%
feature_counts = (
    rho_gff_intersections.groupby(['feature', 'rho_strength'])
    .size()
    .sort_values(ascending=False)
    .reset_index(name="count")
)
feature_counts["percent_intersections"] = ((feature_counts["count"] / feature_counts["count"].sum()).round(6))*100

feature_counts['feature'] = feature_counts["feature"].str.replace('_', ' ')
feature_counts.head(20)
# Out:
# /tmp/ipykernel_114536/2516761400.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#      feature rho_strength  count  percent_intersections
# 0       mRNA       medium  46722                13.6997
# 1       mRNA         high  46237                13.5575
# 2       mRNA          low  46011                13.4913
# 3        CDS          low  41227                12.0885
# 4        CDS         high  40917                11.9976
# 5        CDS       medium  40836                11.9739
# 6       gene         high  23054                 6.7599
# 7       gene       medium  22547                 6.6112
# 8       gene          low  22289                 6.5355
# 9      ncRNA          low   2933                 0.8600
# 10     ncRNA       medium   2271                 0.6659
# 11     ncRNA         high   2100                 0.6158
# 12  misc RNA         high   1255                 0.3680
# 13  misc RNA       medium   1229                 0.3604
# 14  misc RNA          low   1180                 0.3460
# 15      tRNA         high    107                 0.0314
# 16      tRNA       medium     72                 0.0211
# 17      tRNA          low     40                 0.0117
# 18  C region         high      6                 0.0018
# 19  C region       medium      4                 0.0012

# %%
fig = px.bar(
    feature_counts,
    x = 'feature',
    y ='percent_intersections',
    color = "rho_strength",
    title ='% Intersections of Recombination Rate windows per Genomic Feature',
    labels = {'feature': 'Genomic Feature', 'percent_intersections': 'Percent of Intersections', 'rho_strength': 'Recombination Rate'}
)
fig.update_traces(textfont_size=16)
fig.update_layout(yaxis_title="% of Total Intersections", 
                  legend = dict(
                      font = dict(size=16)
                  ),
                 title = dict(
                     font=dict(size=20)
                 ))
fig.show(renderer="iframe")
fig.write_image("Intersections_rho_gff.png", width=800, height=600, scale=6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 fig = px.bar(
# ----> 2     feature_counts,
#       3     x = 'feature',
#       4     y ='percent_intersections',
#       5     color = "rho_strength",
#       6     title ='% Intersections of Recombination Rate windows per Genomic Feature',
#       7     labels = {'feature': 'Genomic Feature', 'percent_intersections': 'Percent of Intersections', 'rho_strength': 'Recombination Rate'}
#       8 )
#       9 fig.update_traces(textfont_size=16)
#      10 fig.update_layout(yaxis_title="% of Total Intersections",
#      11                   legend = dict(
#      12                       font = dict(size=16)
#    (...)
#      15                      font=dict(size=20)
#      16                  ))
#
# NameError: name 'feature_counts' is not defined

# %%
blackcap_genome = (
    pd.read_csv("../input/SylAtri_genome.txt.tsv", sep="\t", usecols=['Chromosome name', 'Seq length'])
    .assign(**{'Chromosome name': lambda df: 'chr' + df['Chromosome name'].astype(str)})
    .head(33)
)
blackcap_genome =
# Out:
#    Chromosome name  Seq length
# 0             chr1   153194430
# 1             chr2   115287908
# 2             chr3   113359798
# 3             chr4    72978054
# 4             chr5    72605035
# 5             chr6    63423007
# 6             chr7    38862568
# 7             chr8    35969369
# 8             chr9    31650914
# 9            chr10    26389481
# 10           chr11    22342531
# 11           chr12    22249080
# 12           chr13    20608123
# 13           chr14    19084229
# 14           chr15    16052774
# 15           chr16    15230834
# 16           chr17    14194216
# 17           chr18    11994622
# 18           chr19    11408529
# 19           chr20    11247436
# 20           chr21    10058197
# 21           chr22     7560935
# 22           chr23     7468107
# 23           chr24     6883216
# 24           chr25     6775589
# 25           chr26     5062550
# 26           chr27     5004062
# 27           chr28     4652909
# 28           chr29     2201499
# 29           chr30     2016562
# 30           chr31      559822
# 31           chr32      436182
# 32           chr33      294449

# %%
def chromsizes_to_dict(genome_file_name: str) -> dict[str, int]:
    genome = pd.read_csv(genome_file_name, sep="\t", header=None)
    return dict(zip(genome[0], genome[1]))

def single_iter(args):
    bed1, bed2, n_samples = args
    bed1_sub = bed1.sample(n=n_samples)
    bed2_sub = bed2.sample(n=n_samples, replace=True)
    return bed1_sub.stats.jaccard(bed2_sub)

def bootstrap_intervals(bed1: pr.PyRanges, bed2: pr.PyRanges, n_samples: int, iterations: int) -> np.ndarray:
    with Pool(processes=cpu_count()) as pool:
        # Prepare arguments list: one tuple per iteration
        args = [(bed1, bed2, n_samples)] * iterations
        results = pool.map(single_iter, args)
    return np.array(results, dtype=np.float64)

def to_pyranges(obj: Union[pr.PyRanges, BedTool, pd.DataFrame]) -> pr.PyRanges:
    """Normalize input to PyRanges."""
    if isinstance(obj, pr.PyRanges):
        return obj
    elif isinstance(obj, BedTool):
        return pr.PyRanges(obj.to_dataframe())
    elif isinstance(obj, pd.DataFrame):
        return pr.PyRanges(obj)
    else:
        raise TypeError("Input must be PyRanges, BedTool, or pandas DataFrame")

def compute_jaccard(
    bed_input1: Union[pr.PyRanges, BedTool, pd.DataFrame],
    bed_input2: Union[pr.PyRanges, BedTool, pd.DataFrame, Mapping[str, Union[pr.PyRanges, BedTool, pd.DataFrame]]],
    genome_file_name: str,
    n_bootstraped_samples: int = 1000,
    iterations: int = 1000
) -> pd.DataFrame:
    
    bed1 = to_pyranges(bed_input1)
    
    # Normalize dict values if dict, else normalize directly
    if isinstance(bed_input2, Mapping):
        bed2_dict = {k: to_pyranges(v) for k, v in bed_input2.items()}
    else:
        bed2_dict = {"All": to_pyranges(bed_input2)}
    
    # Load chrom sizes (if you want to use, currently unused)
    chromsizes = chromsizes_to_dict(genome_file_name)
    
    def summarize_jaccard(jaccard_vals: np.ndarray, feature: str) -> dict:
        return {
        "feature": feature,
        "jaccard_mean": np.mean(jaccard_vals),
        "jaccard_median": np.median(jaccard_vals),
        "ci_lower_95%": np.percentile(jaccard_vals, 2.5),
        "ci_upper_95%": np.percentile(jaccard_vals, 97.5),
        }

    records = [
        summarize_jaccard(bootstrap_intervals(bed1, bed2, n_bootstraped_samples, iterations), feature) for feature, bed2 in bed2_dict.items()
    ]

    return pd.DataFrame.from_records(records)

jaccard_results = compute_jaccard(rec_rate_10kb, features,  n_bootstraped_samples= 1000, iterations=1000, genome_file_name = "../input/blackcap.genome")

# %%
# Calculate error bar lengths relative to the mean
jaccard_results['error_lower'] = jaccard_results['jaccard_mean'] - jaccard_results['ci_lower_95%']
jaccard_results['error_upper'] = jaccard_results['ci_upper_95%'] - jaccard_results['jaccard_mean']

fig = px.bar(
    jaccard_results,
    x="feature",
    y="jaccard_mean",
    error_y=jaccard_results["error_upper"],
    error_y_minus=jaccard_results["error_lower"],
    title="Jaccard Mean with 95% Confidence Intervals by Feature",
    labels={"feature": "Feature", "jaccard_mean": "Jaccard Mean"},
    color="feature",
    color_discrete_sequence=px.colors.qualitative.Plotly,
    width=900,        # width in pixels
    height=600        # height in pixels
)

fig.update_layout(
    yaxis=dict(range=[0, 0.5]),
    xaxis_tickangle=-45,
)

fig.show()
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)

# %%
jaccard_list = pd.DataFrame({"feature": [key for key in features.keys()],
               "jaccard": [rec_rate_10kb.stats.jaccard(feature) for feature in features.values()]}).sort_values(by="jaccard", ascending=False).reset_index()

# %%
fig = px.bar(
    jaccard_list,
    x = "feature",
    y = "jaccard",
    title="Jaccard Index of Recombination Rate with Genomic Feature",
    width=900,
    height=600,
    color="feature"
)

fig.update_layout(
    yaxis=dict(range=[0, 1]),
    xaxis_tickangle=-45,
)

fig.show()

# %%
print(str(len(rec_rate_10kb)))
for feature, bed in features.items():
    print("\t".join([feature, str(len(bed))]))
# Out:
# 94208
# gene	16457
# ncRNA	2172
# mRNA	26215
# CDS	26222
# misc_RNA	643
# tRNA	217
# C_region	4
# V_segment	3

# %%
gff = pr.read_gff3("../input/bSylAtr1.pri.gff")
chromosome_labels = dict(
    pd.read_csv("../input/SylAtri_genome.txt.tsv", sep="\t", header=0)
      .loc[:, ["RefSeq seq accession", "Chromosome name"]]
      .dropna()
      .assign(**{"Chromosome name": lambda df: "chr" + df["Chromosome name"].astype(str)})
      .values
)
gff.head()
# Out:
# +--------------+------------+------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature    |     Start |       End | +52   |
# | (category)   | (object)   | (object)   |   (int64) |   (int64) | ...   |
# |--------------+------------+------------+-----------+-----------+-------|
# | NC_010228.1  | RefSeq     | region     |         0 |     17937 | ...   |
# | NC_010228.1  | RefSeq     | gene       |         0 |        70 | ...   |
# | NC_010228.1  | RefSeq     | tRNA       |         0 |        70 | ...   |
# | NC_010228.1  | RefSeq     | exon       |         0 |        70 | ...   |
# | NC_010228.1  | RefSeq     | gene       |        70 |      1046 | ...   |
# | NC_010228.1  | RefSeq     | rRNA       |        70 |      1046 | ...   |
# | NC_010228.1  | RefSeq     | exon       |        70 |      1046 | ...   |
# | NC_010228.1  | RefSeq     | gene       |      1046 |      1116 | ...   |
# +--------------+------------+------------+-----------+-----------+-------+
# Stranded PyRanges object has 8 rows and 57 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 52 hidden columns: Score, Strand, Frame, ID, Dbxref, Name, chromosome, collected-by, ... (+ 44 more.)

# %%
gff = pr.PyRanges(gff.df.pipe(lambda df: df.assign(Chromosome=df["Chromosome"].map(chromosome_labels)).dropna(subset=["Chromosome"])))
print(gff.head())
gff_subset = pr.PyRanges(
    gff.df.pipe(lambda df: df[(df["Feature"] == "gene") & (df["Chromosome"].str.match(r"chr(?:[1-9]|[1-2][0-9]|3[0-3])"))])[["Chromosome", "Start", "End", "Strand", "Feature", "Name"]]
)
gff_subset
# Out:
# +--------------+------------+------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature    |     Start |       End | +52   |
# | (category)   | (object)   | (object)   |   (int64) |   (int64) | ...   |
# |--------------+------------+------------+-----------+-----------+-------|
# | chr1         | RefSeq     | region     |         0 | 153194430 | ...   |
# | chr1         | Gnomon     | gene       |    112199 |    122771 | ...   |
# | chr1         | Gnomon     | mRNA       |    112199 |    122771 | ...   |
# | chr1         | Gnomon     | exon       |    112199 |    112336 | ...   |
# | chr1         | Gnomon     | exon       |    112574 |    112742 | ...   |
# | chr1         | Gnomon     | exon       |    115090 |    115303 | ...   |
# | chr1         | Gnomon     | exon       |    116209 |    116392 | ...   |
# | chr1         | Gnomon     | exon       |    116697 |    116869 | ...   |
# +--------------+------------+------------+-----------+-----------+-------+
# Stranded PyRanges object has 8 rows and 57 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 52 hidden columns: Score, Strand, Frame, ID, Dbxref, Name, chromosome, collected-by, ... (+ 44 more.)
# +--------------+-----------+-----------+--------------+------------+-------+
# | Chromosome   | Start     | End       | Strand       | Feature    | +1    |
# | (category)   | (int64)   | (int64)   | (category)   | (object)   | ...   |
# |--------------+-----------+-----------+--------------+------------+-------|
# | chr1         | 112199    | 122771    | +            | gene       | ...   |
# | chr1         | 126172    | 127619    | +            | gene       | ...   |
# | chr1         | 135232    | 143451    | +            | gene       | ...   |
# | chr1         | 155021    | 161918    | +            | gene       | ...   |
# | ...          | ...       | ...       | ...          | ...        | ...   |
# | chr33        | 186098    | 186458    | -            | gene       | ...   |
# | chr33        | 201295    | 202041    | -            | gene       | ...   |
# | chr33        | 237392    | 239411    | -            | gene       | ...   |
# | chr33        | 259608    | 260145    | -            | gene       | ...   |
# +--------------+-----------+-----------+--------------+------------+-------+
# Unstranded PyRanges object has 16,236 rows and 6 columns from 33 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 1 hidden columns: Name

# %%
rec_rate_10kb.df[rec_rate_10kb.df["Chromosome"] == "chr1"][["Chromosome", "Score"]].sort_values(by="Score", ascending=False)
# Out:
#       Chromosome       Score
# 15154       chr1  196.653177
# 15150       chr1  183.419222
# 113         chr1  178.045426
# 15159       chr1  170.818489
# 112         chr1  164.206686
# ...          ...         ...
# 5686        chr1    0.010768
# 5685        chr1    0.010689
# 5696        chr1    0.009107
# 5695        chr1    0.009107
# 5700        chr1    0.004601
#
# [15240 rows x 2 columns]
