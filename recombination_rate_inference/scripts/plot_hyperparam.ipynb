# %%
# %pip install python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
from typing import List, Union, Optional, Dict

# %%
def load_txt_file(file_name: str) -> pd.DataFrame:
    return pd.read_csv
